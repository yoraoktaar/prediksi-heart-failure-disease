# %% [markdown]
# #### Business Understanding

# %% [markdown]
# Business Problem:
#    Bagaimana cara meningkatkan angka kelangsungan hidup penyakit gagal jantung dengan melakukan early deteksi atau prediksi berdasarkan data uji klinis?
#
# Objective:
#    Membangun model klasifikasi untuk memprediksi kemungkinan penyakit gagal jantung.

# %% [markdown]
# #### Data Cleansing

# %%
import pandas as pd

# %%
df = pd.read_csv("heart_disease.csv")
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
## Check missing values

# %%
df.isna().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
## Check outliers

# %%
for col in df.columns:
    print(f"Running for {col}")
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    fence_high = q3 + 1.5*iqr 
    fence_low = q1 - 1.5*iqr 
    outliers = df[(df[col] < fence_low) | (df[col] > fence_high)]
    print(outliers.shape)
# Out:
# Running for age
# (0, 12)
# Running for sex
# (281, 12)
# Running for chest pain type
# (66, 12)
# Running for resting bp s
# (37, 12)
# Running for cholesterol
# (193, 12)
# Running for fasting blood sugar
# (254, 12)
# Running for resting ecg
# (0, 12)
# Running for max heart rate
# (1, 12)
# Running for exercise angina
# (0, 12)
# Running for oldpeak
# (11, 12)
# Running for ST slope
# (0, 12)
# Running for target
# (0, 12)

# %%
for col in df.columns:
    print(f"Running for {col}")
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    fence_high = q3 + 1.5*iqr 
    fence_low = q1 - 1.5*iqr 
    outliers = df[(df[col] < fence_low) | (df[col] > fence_high)]
    df = df[(df[col] >= fence_low) & (df[col] <= fence_high)]
# Out:
# Running for age
# Running for sex
# Running for chest pain type
# Running for resting bp s
# Running for cholesterol
# Running for fasting blood sugar
# Running for resting ecg
# Running for max heart rate
# Running for exercise angina
# Running for oldpeak
# Running for ST slope
# Running for target

# %%
df.shape
# Out:
# (562, 12)

# %%
df
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 2      37    1                2           130          283
# 4      54    1                3           150          195
# 5      39    1                3           120          339
# 7      54    1                2           110          208
# ...   ...  ...              ...           ...          ...
# 1179   44    1                4           120          169
# 1180   63    1                4           140          187
# 1182   41    1                2           120          157
# 1187   57    1                4           130          131
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 2                       0            1              98                0
# 4                       0            0             122                0
# 5                       0            0             170                0
# 7                       0            0             142                0
# ...                   ...          ...             ...              ...
# 1179                    0            0             144                1
# 1180                    0            2             144                1
# 1182                    0            0             182                0
# 1187                    0            0             115                1
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target
# 0         0.0         1       0
# 2         0.0         1       0
# 4         0.0         1       0
# 5         0.0         1       0
# 7         0.0         1       0
# ...       ...       ...     ...
# 1179      2.8         3       1
# 1180      4.0         1       1
# 1182      0.0         1       0
# 1187      1.2         2       1
# 1189      0.0         1       0
#
# [562 rows x 12 columns]

# %%
## Check duplicates

# %%
df.duplicated().sum()
# Out:
# 141

# %% [markdown]
# #### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 562 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  562 non-null    int64
#  1   sex                  562 non-null    int64
#  2   chest pain type      562 non-null    int64
#  3   resting bp s         562 non-null    int64
#  4   cholesterol          562 non-null    int64
#  5   fasting blood sugar  562 non-null    int64
#  6   resting ecg          562 non-null    int64
#  7   max heart rate       562 non-null    int64
#  8   exercise angina      562 non-null    int64
#  9   oldpeak              562 non-null    float64
#  10  ST slope             562 non-null    int64
#  11  target               562 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 57.1 KB

# %%
## Univriate Analysis

# %%
df.describe()
# Out:
#               age    sex  chest pain type  resting bp s  cholesterol  \
# count  562.000000  562.0       562.000000    562.000000   562.000000
# mean    52.373665    1.0         3.366548    130.190391   239.256228
# std      9.448569    0.0         0.801615     14.959638    48.276741
# min     28.000000    1.0         2.000000     92.000000    85.000000
# 25%     45.000000    1.0         3.000000    120.000000   207.250000
# 50%     53.000000    1.0         4.000000    130.000000   235.000000
# 75%     59.000000    1.0         4.000000    140.000000   271.750000
# max     77.000000    1.0         4.000000    170.000000   388.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count                562.0   562.000000      562.000000       562.000000
# mean                   0.0     0.676157      140.514235         0.425267
# std                    0.0     0.886682       24.924856         0.494824
# min                    0.0     0.000000       71.000000         0.000000
# 25%                    0.0     0.000000      122.000000         0.000000
# 50%                    0.0     0.000000      140.000000         0.000000
# 75%                    0.0     2.000000      160.000000         1.000000
# max                    0.0     2.000000      202.000000         1.000000
#
#           oldpeak    ST slope      target
# count  562.000000  562.000000  562.000000
# mean     0.981851    1.580071    0.544484
# std      1.098496    0.592431    0.498461
# min     -0.100000    1.000000    0.000000
# 25%      0.000000    1.000000    0.000000
# 50%      0.600000    2.000000    1.000000
# 75%      1.800000    2.000000    1.000000
# max      4.400000    3.000000    1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (15,7))
for i in range(len(df.columns)):
    plt.subplot(2,6,i+1)
    sns.histplot(x = df.columns[i], data = df)
    plt.tight_layout()

# %%
## Multivariate Analysis

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Additional Data Preparation before Modeling

# %%
# feature Engineering

# %%
df["max_heart_rate_per_age"] = df["max heart rate"] / df ["age"]
df
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 2      37    1                2           130          283
# 4      54    1                3           150          195
# 5      39    1                3           120          339
# 7      54    1                2           110          208
# ...   ...  ...              ...           ...          ...
# 1179   44    1                4           120          169
# 1180   63    1                4           140          187
# 1182   41    1                2           120          157
# 1187   57    1                4           130          131
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 2                       0            1              98                0
# 4                       0            0             122                0
# 5                       0            0             170                0
# 7                       0            0             142                0
# ...                   ...          ...             ...              ...
# 1179                    0            0             144                1
# 1180                    0            2             144                1
# 1182                    0            0             182                0
# 1187                    0            0             115                1
# 1189                    0            0             173                0
#
#       oldpeak  ST slope  target  max_heart_rate_per_age
# 0         0.0         1       0                4.300000
# 2         0.0         1       0                2.648649
# 4         0.0         1       0                2.259259
# 5         0.0         1       0                4.358974
# 7         0.0         1       0                2.629630
# ...       ...       ...     ...                     ...
# 1179      2.8         3       1                3.272727
# 1180      4.0         1       1                2.285714
# 1182      0.0         1       0                4.439024
# 1187      1.2         2       1                2.017544
# 1189      0.0         1       0                4.552632
#
# [562 rows x 13 columns]

# %%
## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns = ["target"])
y = df["target"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (449, 12)
# (113, 12)
# (449,)
# (113,)

# %% [markdown]
# #### Modeling & Evaluation

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
##Hyperparameter Tuning

# %%
params = {
    "max_depth": [2,3,4,5,10,15],
    "min_samples_leaf": [10,15,20,50,100]
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator = RandomForestClassifier(),
                           param_grid = params,
                           cv = 5,
                           scoring = "roc_auc")
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 3, 4, 5, 10, 15],
#                          'min_samples_leaf': [10, 15, 20, 50, 100]},
#              scoring='roc_auc')

# %%
rf_best = grid_search.best_estimator_
rf_best.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=15, min_samples_leaf=10)

# %%
##Evaluation

# %%
from sklearn.metrics import recall_score

y_dtree = dtree.predict(X_test)
y_rf = rf.predict(X_test)
y_rfbest = rf_best.predict(X_test)

# %%
print(recall_score(y_test, y_dtree, pos_label = 1, average = "binary"))
print(recall_score(y_test, y_rf, pos_label = 1, average = "binary"))
print(recall_score(y_test, y_rfbest, pos_label = 1, average = "binary"))
# Out:
# 0.9230769230769231
# 0.9384615384615385
# 0.8

# %%
from sklearn.metrics import precision_score

print(precision_score(y_test, y_dtree, pos_label = 1, average = "binary"))
print(precision_score(y_test, y_rf, pos_label = 1, average = "binary"))
print(precision_score(y_test, y_rfbest, pos_label = 1, average = "binary"))
# Out:
# 0.8695652173913043
# 0.9242424242424242
# 0.8387096774193549

# %%
from sklearn.metrics import roc_auc_score

y_prob_dtree = dtree.predict_proba(X_test)[:,1]
y_prob_rf = rf.predict_proba(X_test)[:,1]
y_prob_rfbest = rf_best.predict_proba(X_test)[:,1]

# %%
print(roc_auc_score(y_test, y_prob_dtree))
print(roc_auc_score(y_test, y_prob_rf))
print(roc_auc_score(y_test, y_prob_rfbest))
# Out:
# 0.8677884615384616
# 0.9657051282051282
# 0.9083333333333334

# %% [markdown]
# #### Business Conclusion

# %% [markdown]
# Business Impact
#
# Final model = Random Forest without Hyperparameter Tuning
#
# Recall = 94%, Precision = 92%
#
# Assume: untuk setiap 100 pasien, 50 akan punya penyakit gagal jantung.
#
# 1. Before the model:
#    - Kita tidak melakukan early deteksi, jadi assume tingkat kelangsungan hidup 50%. Maka hanya 25 pasien yang akan survive.
# 2. After the model:
#    - Kita tahu siapa yang akan punya heart failure disease.
#    - With 94% recall, akan dilakukan early detection for 0.94% * 50 = 47 patients
#    - Dengan assume knowing early, survival rate akan meningkat to 75%
#    - 0.75*47 = 35 akan survive
